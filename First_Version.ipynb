# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from scipy.ndimage.interpolation import shift
import pickle

# %%
img = cv2.imread("images/wolf.png",0)

# %%
img = [[0]*256]*256
for i in range(256):
    for j in range(256):
        img[i][j] = (i**2-j**2)

# %%
plt.imshow(img)

# %%
#dividing into blocks of 16*16
rows = len(img)
cols = len(img[0])

blk_sz_x = 32
blk_sz_y = 32

num_blk_x = rows//blk_sz_x
num_blk_y = cols//blk_sz_y
num_blk = num_blk_x*num_blk_y

# %%
#block stores all the puzzle blocks
def divide_image(img,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y):
    blocks = []

    for i in range(num_blk_x):
        for j in range(num_blk_y):
            block = []
            for k in range(blk_sz_x):
                block.append(img[i*blk_sz_x+k][j*blk_sz_y:(j+1)*blk_sz_y])
            blocks.append(np.array(block))
    return blocks

# %%
blocks = divide_image(img,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y)

# %%
#initializing a random population
def init_population(ppl_sz,num_blk_x,num_blk_y,num_blk):

    population = []

    for i in range(ppl_sz):
        population.append(np.random.permutation(num_blk).reshape(num_blk_x,num_blk_y))

    return population

# %%
population = init_population(1000,num_blk_x,num_blk_y,num_blk)

# %%
def get_image(specie,blocks):
    img_specie_row = []
    for i in range(num_blk_x):
        row = blocks[specie[i][0]]
        for j in range(1,num_blk_y):
            row = np.concatenate((row,blocks[specie[i][j]]),axis=1)
        img_specie_row.append(row)
        
    img_specie = img_specie_row[0]
    for i in range(1,num_blk_x):
        img_specie = np.concatenate((img_specie,img_specie_row[i]),axis=0)
    return img_specie

# %%
def visual_specie(specie, blocks):
    plt.imshow(get_image(specie,blocks))

# %%
visual_specie(population[0],blocks)
#visual_specie(np.arange(num_blk).reshape(num_blk_x,num_blk_y),blocks)

# %%
def compute_cost(specie,blocks,num_blk_x,num_blk_y):
    cost = 0
    for i in range(num_blk_x-1):
        for j in range(num_blk_y-1):
            p = specie[i][j]
            p1 = specie[i+1][j]
            p2 = specie[i][j+1]
            cost += np.sum(abs(blocks[p][-1] - blocks[p1][0]))
            cost += np.sum(abs(blocks[p].T[-1] - blocks[p2].T[0]))
    return cost

# %%
#compute_cost(population[0],blocks,num_blk_x,num_blk_y)
compute_cost(np.arange(num_blk).reshape(num_blk_x,num_blk_y),blocks,num_blk_x,num_blk_y)
# Out:
# 399840

# %%
bst = 0
bstcst = compute_cost(population[0],blocks,num_blk_x,num_blk_y)
for i in range(len(population)):
    cost = compute_cost(population[i],blocks,num_blk_x,num_blk_y)
    if cost <= bstcst:
        bst = i
        bstcst = cost
print(bstcst)
visual_specie(population[bst],blocks)
# Out:
# 52996192

# %%
def elite_species(population,blocks,num_blk_x,num_blk_y,elite_pt):
    cost = []
    for member in population:
        cost.append(compute_cost(member,blocks,num_blk_x,num_blk_y))
    zipped_list = zip(cost,population)
    sorted_zipped_list = sorted(zipped_list, key=lambda x: x[0])
    new_population = [element for _, element in sorted_zipped_list]
    
    mid = int(elite_pt*len(population))
    
    return new_population[:mid]

# %%
def elite_diversity(elite):
    cost = []
    for i in elite:
        cost.append(compute_cost(i,blocks,num_blk_x,num_blk_y))
    return len(set(cost))

# %%
def next_gen(population,blocks,num_blk_x,num_blk_y,ppl_sz):
    cost = []
    for member in population:
        cost.append(compute_cost(member,blocks,num_blk_x,num_blk_y))
    zipped_list = zip(cost,population)
    sorted_zipped_list = sorted(zipped_list,key=lambda x: x[0])
    new_pop = [element for _, element in sorted_zipped_list]
    cost.sort()
    next_pop = [new_pop[0]]
    ind = 1
    while len(next_pop)<int(0.3*ppl_sz) and ind<len(new_pop):
        if cost[ind-1]!=cost[ind]:
            next_pop.append(new_pop[ind])
        ind+=1
    random.shuffle(new_pop)
    next_pop.extend(new_pop[:ppl_sz-len(next_pop)])
    return next_pop

# %%
def apply_patch(mat,pch,top,h,w):
    dic = {}
    for i in range(len(mat)):
        for j in range(len(mat[0])):
            dic[mat[i][j]] = (i,j)
            
    m = mat.copy()
    for i in range(h):
        for j in range(w):
            p1 = pch[i][j]
            p2 = m[top[0]+i][top[1]+j]
            lp1 = dic[p1]
            lp2 = dic[p2]
            m[lp1[0]][lp1[1]] = p2
            m[lp2[0]][lp2[1]] = p1
            dic[p1] = lp2
            dic[p2] = lp1
    return m

# %%
def crossover1(m1,m2,blocks,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y):
    top = (random.randint(0,num_blk_x-1),random.randint(0,num_blk_y-1))
    bot = (random.randint(top[0],num_blk_x-1),random.randint(top[1],num_blk_y-1))
    h = bot[0]-top[0]+1
    w = bot[1]-top[1]+1
    new_top = (random.randint(0,num_blk_x-h),random.randint(0,num_blk_y-w))
    pt1 = m1[top[0]:bot[0]+1,top[1]:bot[1]+1]
    pt2 = m2[new_top[0]:new_top[0]+h, new_top[1]:new_top[1]+w]
    p1 = apply_patch(m1,pt2,top,h,w)
    p2 = apply_patch(m2,pt1,new_top,h,w)
    return p1,p2

# %%
def mutate(m,blocks,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y):
    if(random.random()>0.5):
        x = random.randint(0,num_blk_x)
        return np.append(m[x:],m[:x],axis=0)
    else:
        y = random.randint(0,num_blk_y)
        return np.append(m.T[y:],m.T[:y],axis=0)

# %%
def self_mutate(mat,blocks,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y):
    m = mat.copy()
    cell1 = (random.randint(0,num_blk_x-1),random.randint(0,num_blk_y-1))
    cell2 = (random.randint(0,num_blk_x-1),random.randint(0,num_blk_y-1))
    tmp = m[cell1[0]][cell1[1]]
    m[cell1[0]][cell1[1]] = m[cell2[0]][cell2[1]]
    m[cell2[0]][cell2[1]] = tmp
    return m

# %%
total_gen = 1500
best_specie_gen = []
curr_gen = 0
ppl_sz = 100

rows = len(img)
cols = len(img[0])

blk_sz_x =32
blk_sz_y =32

num_blk_x = rows//blk_sz_x
num_blk_y = cols//blk_sz_y
num_blk = num_blk_x*num_blk_y

elite_pt = 0.05

blocks = divide_image(img,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y)

population = init_population(ppl_sz,num_blk_x,num_blk_y,num_blk)

bst = 0
bstcst = compute_cost(population[0],blocks,num_blk_x,num_blk_y)
for i in range(len(population)):
    cost = compute_cost(population[i],blocks,num_blk_x,num_blk_y)
    if cost <= bstcst:
        bst = i
        bstcst = cost
print(bstcst)
visual_specie(population[bst],blocks)
# Out:
# 51240288

# %%
visual_specie(np.arange(num_blk).reshape(num_blk_x,num_blk_y),blocks)
compute_cost(np.arange(num_blk).reshape(num_blk_x,num_blk_y),blocks,num_blk_x,num_blk_y)
# Out:
# 399840

# %%
for gen in range(curr_gen,total_gen):
    elite = elite_species(population,blocks,num_blk_x,num_blk_y,elite_pt)
    if gen%50==0:
        print("Elite diversity: "+str(elite_diversity(elite)))
    """
    mip = 1000000000
    for i in population:
        mip = min(mip,compute_cost(i,blocks,num_blk_x,num_blk_y))
    mie = 1000000000
    for i in elite:
        mie = min(mie,compute_cost(i,blocks,num_blk_x,num_blk_y))
    print("mip: "+str(mip))
    print("mie: "+str(mie))
    print("elite[0]: "+str(compute_cost(elite[0],blocks,num_blk_x,num_blk_y)))
    """
    #print(elite)
    random.shuffle(population)
    #print(elite)
    new_population = population[:]

    #print(elite)
    #print(new_population)
    for i in range(0,len(population),2):
        cross_pbt = random.random()
        if cross_pbt<0.7:
            p1,p2 = crossover1(population[i],population[i+1],blocks,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y)
            new_population.append(p1)
            new_population.append(p2)

    """
    mix = 1000000000
    #print("cost: "+str(compute_cost(new_population[0],blocks,num_blk_x,num_blk_y)))
    #print("elite[0]: "+str(compute_cost(elite[0],blocks,num_blk_x,num_blk_y)))
    #print((new_population[0]==elite[0]))
    #print(compute_cost(new_population[0],blocks,num_blk_x,num_blk_y) == compute_cost(elite[0],blocks,num_blk_x,num_blk_y))
    for i in new_population:
        mix = min(mix,compute_cost(i,blocks,num_blk_x,num_blk_y))
    print("mix: "+str(mix))
    """
    for i in range(0,len(new_population)):
        if random.random()<0.1:
            new_population.append(mutate(new_population[i],blocks,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y))
        elif random.random()<0.1:
            new_population.append(self_mutate(new_population[i],blocks,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y))

    #print(elite)
    #new_population.extend(elite)

    population = next_gen(new_population,blocks,num_blk_x,num_blk_y,ppl_sz)
    """
    mid = 1000000000
    for i in population:
        mid = min(mid,compute_cost(i,blocks,num_blk_x,num_blk_y))
    print("mid: "+str(mid))
    """
    best_specie_gen.append(population[0])
    if gen%10==9:
        print(str(gen+1)+" generation completed. Best cost: "+str(compute_cost(best_specie_gen[-1],blocks,num_blk_x,num_blk_y)))
    
    curr_gen += 1
# Out:
# Elite diversity: 5
# 10 generation completed. Best cost: 46021856
# 20 generation completed. Best cost: 43052000
# 30 generation completed. Best cost: 38680480
# 40 generation completed. Best cost: 36746976
# 50 generation completed. Best cost: 31722080
# Elite diversity: 3
# 60 generation completed. Best cost: 29371040
# 70 generation completed. Best cost: 29371040
# 80 generation completed. Best cost: 28507744
# 90 generation completed. Best cost: 26713440
# 100 generation completed. Best cost: 26625504
# Elite diversity: 2
# 110 generation completed. Best cost: 24753504
# 120 generation completed. Best cost: 24753504
# 130 generation completed. Best cost: 23193184
# 140 generation completed. Best cost: 22135456
# 150 generation completed. Best cost: 18590176
# Elite diversity: 3
# 160 generation completed. Best cost: 18590176
# 170 generation completed. Best cost: 17634720
# 180 generation completed. Best cost: 16991712
# 190 generation completed. Best cost: 16991712
# 200 generation completed. Best cost: 15972896
# Elite diversity: 3
# 210 generation completed. Best cost: 15340960
# 220 generation completed. Best cost: 15211872
# 230 generation completed. Best cost: 15020320
# 240 generation completed. Best cost: 14643488
# 250 generation completed. Best cost: 13487264
# Elite diversity: 4
# 260 generation completed. Best cost: 12869920
# 270 generation completed. Best cost: 12622112
# 280 generation completed. Best cost: 12593440
# 290 generation completed. Best cost: 10213600
# 300 generation completed. Best cost: 10213600
# Elite diversity: 2
# 310 generation completed. Best cost: 10013856
# 320 generation completed. Best cost: 9471072
# 330 generation completed. Best cost: 8448160
# 340 generation completed. Best cost: 8351968
# 350 generation completed. Best cost: 7973024
# Elite diversity: 3
# 360 generation completed. Best cost: 7848032
# 370 generation completed. Best cost: 7848032
# 380 generation completed. Best cost: 7092192
# 390 generation completed. Best cost: 7092192
# 400 generation completed. Best cost: 6555744
# Elite diversity: 3
# 410 generation completed. Best cost: 6539552
# 420 generation completed. Best cost: 6539552
# 430 generation completed. Best cost: 6434848
# 440 generation completed. Best cost: 5666784
# 450 generation completed. Best cost: 5666784
# Elite diversity: 3
# 460 generation completed. Best cost: 5342176
# 470 generation completed. Best cost: 5212192
# 480 generation completed. Best cost: 5084128
# 490 generation completed. Best cost: 4789280
# 500 generation completed. Best cost: 4473824
# Elite diversity: 3
# 510 generation completed. Best cost: 4473824
# 520 generation completed. Best cost: 4473824
# 530 generation completed. Best cost: 4473824
# 540 generation completed. Best cost: 4440032
# 550 generation completed. Best cost: 4349856
# Elite diversity: 4
# 560 generation completed. Best cost: 4126624
# 570 generation completed. Best cost: 4126624
# 580 generation completed. Best cost: 4126624
# 590 generation completed. Best cost: 3820512
# 600 generation completed. Best cost: 3820512
# Elite diversity: 4
# 610 generation completed. Best cost: 3739488
# 620 generation completed. Best cost: 3739488
# 630 generation completed. Best cost: 3631008
# 640 generation completed. Best cost: 3631008
# 650 generation completed. Best cost: 3481376
# Elite diversity: 3
# 660 generation completed. Best cost: 3481376
# 670 generation completed. Best cost: 3262432
# 680 generation completed. Best cost: 3262432
# 690 generation completed. Best cost: 2714336
# 700 generation completed. Best cost: 2714336
# Elite diversity: 3
# 710 generation completed. Best cost: 2583264
# 720 generation completed. Best cost: 2221792
# 730 generation completed. Best cost: 2221792
# 740 generation completed. Best cost: 2087712
# 750 generation completed. Best cost: 1672928
# Elite diversity: 3
# 760 generation completed. Best cost: 1672928
# 770 generation completed. Best cost: 1522272
# 780 generation completed. Best cost: 1322656
# 790 generation completed. Best cost: 810592
# 800 generation completed. Best cost: 718368
# Elite diversity: 3
# 810 generation completed. Best cost: 718368
# 820 generation completed. Best cost: 718368
# 830 generation completed. Best cost: 718368
# 840 generation completed. Best cost: 621088
# 850 generation completed. Best cost: 528864
# Elite diversity: 3
# 860 generation completed. Best cost: 528864
# 870 generation completed. Best cost: 528864
# 880 generation completed. Best cost: 528864
# 890 generation completed. Best cost: 528864
# 900 generation completed. Best cost: 528864
# Elite diversity: 3
# 910 generation completed. Best cost: 528864
# 920 generation completed. Best cost: 528864
# 930 generation completed. Best cost: 399840
# 940 generation completed. Best cost: 399840
# 950 generation completed. Best cost: 399840
# Elite diversity: 3
# 960 generation completed. Best cost: 399840
# 970 generation completed. Best cost: 399840
# 980 generation completed. Best cost: 399840
# 990 generation completed. Best cost: 399840
# 1000 generation completed. Best cost: 399840
# Elite diversity: 3
# 1010 generation completed. Best cost: 399840
# 1020 generation completed. Best cost: 399840
# 1030 generation completed. Best cost: 399840
# 1040 generation completed. Best cost: 399840
# 1050 generation completed. Best cost: 399840
# Elite diversity: 3
# 1060 generation completed. Best cost: 399840
# 1070 generation completed. Best cost: 399840
# 1080 generation completed. Best cost: 399840
# 1090 generation completed. Best cost: 399840
# 1100 generation completed. Best cost: 399840
# Elite diversity: 3
# 1110 generation completed. Best cost: 399840
# 1120 generation completed. Best cost: 399840
# 1130 generation completed. Best cost: 399840
# 1140 generation completed. Best cost: 399840
# 1150 generation completed. Best cost: 399840
# Elite diversity: 4
# 1160 generation completed. Best cost: 399840
# 1170 generation completed. Best cost: 399840
# 1180 generation completed. Best cost: 399840
# 1190 generation completed. Best cost: 399840
# 1200 generation completed. Best cost: 399840
# Elite diversity: 2
# 1210 generation completed. Best cost: 399840
# 1220 generation completed. Best cost: 399840
# 1230 generation completed. Best cost: 399840
# 1240 generation completed. Best cost: 399840
# 1250 generation completed. Best cost: 399840
# Elite diversity: 4
# 1260 generation completed. Best cost: 399840
# 1270 generation completed. Best cost: 399840
# 1280 generation completed. Best cost: 399840
# 1290 generation completed. Best cost: 399840
# 1300 generation completed. Best cost: 399840
# Elite diversity: 3
# 1310 generation completed. Best cost: 399840
# 1320 generation completed. Best cost: 399840
# 1330 generation completed. Best cost: 399840
# 1340 generation completed. Best cost: 399840
# 1350 generation completed. Best cost: 399840
# Elite diversity: 4
# 1360 generation completed. Best cost: 399840
# 1370 generation completed. Best cost: 399840
# 1380 generation completed. Best cost: 399840
# 1390 generation completed. Best cost: 399840
# 1400 generation completed. Best cost: 399840
# Elite diversity: 4
# 1410 generation completed. Best cost: 399840
# 1420 generation completed. Best cost: 399840
# 1430 generation completed. Best cost: 399840
# 1440 generation completed. Best cost: 399840
# 1450 generation completed. Best cost: 399840
# Elite diversity: 2
# 1460 generation completed. Best cost: 399840
# 1470 generation completed. Best cost: 399840
# 1480 generation completed. Best cost: 399840
# 1490 generation completed. Best cost: 399840
# 1500 generation completed. Best cost: 399840

# %%
total_gen = 5000

# %%
ind = -1
visual_specie(best_specie_gen[ind],blocks)
compute_cost(best_specie_gen[ind],blocks,num_blk_x,num_blk_y)
# Out:
# 399840

# %%
y = []
x = []
for i in range(len(best_specie_gen)):
    y.append(compute_cost(best_specie_gen[i],blocks,num_blk_x,num_blk_y))
    x.append(i+1)
plt.plot(x,y)

# %%
ind = 75
visual_specie(best_specie_gen[ind],blocks)
compute_cost(best_specie_gen[ind],blocks,num_blk_x,num_blk_y)
# Out:
# 137236.0

# %%
total_gen = 3000

# %%
print(len(best_specie_gen))
# Out:
# 100

# %%
visual_specie(best_specie_gen[9998],blocks)
compute_cost(best_specie_gen[9998],blocks,num_blk_x,num_blk_y)
# Out:
# 20960

# %%
visual_specie(best_specie_gen[-1],blocks)
compute_cost(best_specie_gen[-1],blocks,num_blk_x,num_blk_y)
# Out:
# 20416

# %%
with open("16*16_10k-gen.pkl","wb") as f:
    pickle.dump([best_specie_gen, population, curr_gen],f)

# %%
visual_specie(population[0],blocks)
