# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import random
from scipy.ndimage.interpolation import shift
import pickle

# %%
for i in range(256):
    for j in range(256):
        img[i][j] = (i**2-j**2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-adacb45167d4> in <module>
#       1 for i in range(256):
#       2     for j in range(256):
# ----> 3         img[i][j] = (i**2-j**2)
#
# NameError: name 'img' is not defined

# %%
img = cv2.imread("images/wolf.png",0)

# %%
plt.imshow(img)

# %%
#dividing into blocks of 16*16
rows = len(img)
cols = len(img[0])

blk_sz_x = 32
blk_sz_y = 32

num_blk_x = rows//blk_sz_x
num_blk_y = cols//blk_sz_y
num_blk = num_blk_x*num_blk_y

# %%
#block stores all the puzzle blocks
def divide_image(img,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y):
    blocks = []

    for i in range(num_blk_x):
        for j in range(num_blk_y):
            block = []
            for k in range(blk_sz_x):
                block.append(img[i*blk_sz_x+k][j*blk_sz_y:(j+1)*blk_sz_y])
            blocks.append(np.array(block))
    return blocks

# %%
blocks = divide_image(img,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y)

# %%
#initializing a random population
def init_population(ppl_sz,num_blk_x,num_blk_y,num_blk):

    population = []

    for i in range(ppl_sz):
        population.append(np.random.permutation(num_blk).reshape(num_blk_x,num_blk_y))

    return population

# %%
population = init_population(1000,num_blk_x,num_blk_y,num_blk)

# %%
def get_image(specie,blocks):
    img_specie_row = []
    for i in range(num_blk_x):
        row = blocks[specie[i][0]]
        for j in range(1,num_blk_y):
            row = np.concatenate((row,blocks[specie[i][j]]),axis=1)
        img_specie_row.append(row)
        
    img_specie = img_specie_row[0]
    for i in range(1,num_blk_x):
        img_specie = np.concatenate((img_specie,img_specie_row[i]),axis=0)
    return img_specie

# %%
def visual_specie(specie, blocks):
    plt.imshow(get_image(specie,blocks))

# %%
visual_specie(population[0],blocks)
#visual_specie(np.arange(num_blk).reshape(num_blk_x,num_blk_y),blocks)

# %%
def compute_cost(specie,blocks,num_blk_x,num_blk_y):
    cost = 0
    for i in range(num_blk_x-1):
        for j in range(num_blk_y-1):
            p = specie[i][j]
            p1 = specie[i+1][j]
            p2 = specie[i][j+1]
            cost += np.sum(abs(blocks[p][-1] - blocks[p1][0]))
            cost += np.sum(abs(blocks[p].T[-1] - blocks[p2].T[0]))
    return cost

# %%
#compute_cost(population[0],blocks,num_blk_x,num_blk_y)
compute_cost(np.arange(num_blk).reshape(num_blk_x,num_blk_y),blocks,num_blk_x,num_blk_y)
# Out:
# 95271.0

# %%
bst = 0
bstcst = compute_cost(population[0],blocks,num_blk_x,num_blk_y)
for i in range(len(population)):
    cost = compute_cost(population[i],blocks,num_blk_x,num_blk_y)
    if cost <= bstcst:
        bst = i
        bstcst = cost
print(bstcst)
visual_specie(population[bst],blocks)
# Out:
# 268323.0

# %%
def elite_species(population,blocks,num_blk_x,num_blk_y,elite_pt):
    cost = []
    for member in population:
        cost.append(compute_cost(member,blocks,num_blk_x,num_blk_y))
    zipped_list = zip(cost,population)
    sorted_zipped_list = sorted(zipped_list, key=lambda x: x[0])
    new_population = [element for _, element in sorted_zipped_list]
    
    mid = int(elite_pt*len(population))
    
    return new_population[:mid]

# %%
def elite_diversity(elite):
    cost = []
    for i in elite:
        cost.append(compute_cost(i,blocks,num_blk_x,num_blk_y))
    return len(set(cost))

# %%
def next_gen(population,blocks,num_blk_x,num_blk_y,ppl_sz):
    cost = []
    for member in population:
        cost.append(compute_cost(member,blocks,num_blk_x,num_blk_y))
    zipped_list = zip(cost,population)
    sorted_zipped_list = sorted(zipped_list,key=lambda x: x[0])
    new_pop = [element for _, element in sorted_zipped_list]
    cost.sort()
    next_pop = [new_pop[0]]
    ind = 1
    while len(next_pop)<int(0.3*ppl_sz) and ind<len(new_pop):
        if cost[ind-1]!=cost[ind]:
            next_pop.append(new_pop[ind])
        ind+=1
    random.shuffle(new_pop)
    next_pop.extend(new_pop[:ppl_sz-len(next_pop)])
    return next_pop

# %%
def apply_patch(mat,pch,top,h,w):
    dic = {}
    for i in range(len(mat)):
        for j in range(len(mat[0])):
            dic[mat[i][j]] = (i,j)
            
    m = mat.copy()
    for i in range(h):
        for j in range(w):
            p1 = pch[i][j]
            p2 = m[top[0]+i][top[1]+j]
            lp1 = dic[p1]
            lp2 = dic[p2]
            m[lp1[0]][lp1[1]] = p2
            m[lp2[0]][lp2[1]] = p1
            dic[p1] = lp2
            dic[p2] = lp1
    return m

# %%
def crossover1(m1,m2,blocks,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y):
    top = (random.randint(0,num_blk_x-1),random.randint(0,num_blk_y-1))
    bot = (random.randint(top[0],num_blk_x-1),random.randint(top[1],num_blk_y-1))
    h = bot[0]-top[0]+1
    w = bot[1]-top[1]+1
    new_top = (random.randint(0,num_blk_x-h),random.randint(0,num_blk_y-w))
    pt1 = m1[top[0]:bot[0]+1,top[1]:bot[1]+1]
    pt2 = m2[new_top[0]:new_top[0]+h, new_top[1]:new_top[1]+w]
    p1 = apply_patch(m1,pt2,top,h,w)
    p2 = apply_patch(m2,pt1,new_top,h,w)
    return p1,p2

# %%
def mutate(m,blocks,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y):
    if(random.random()>0.5):
        x = random.randint(0,num_blk_x)
        return np.append(m[x:],m[:x],axis=0)
    else:
        y = random.randint(0,num_blk_y)
        return np.append(m.T[y:],m.T[:y],axis=0)

# %%
def self_mutate(mat,blocks,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y):
    m = mat.copy()
    cell1 = (random.randint(0,num_blk_x-1),random.randint(0,num_blk_y-1))
    cell2 = (random.randint(0,num_blk_x-1),random.randint(0,num_blk_y-1))
    tmp = m[cell1[0]][cell1[1]]
    m[cell1[0]][cell1[1]] = m[cell2[0]][cell2[1]]
    m[cell2[0]][cell2[1]] = tmp
    return m

# %%
total_gen = 1500
best_specie_gen = []
curr_gen = 0
ppl_sz = 100

rows = len(img)
cols = len(img[0])

blk_sz_x =32
blk_sz_y =32

num_blk_x = rows//blk_sz_x
num_blk_y = cols//blk_sz_y
num_blk = num_blk_x*num_blk_y

elite_pt = 0.05

blocks = divide_image(img,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y)

population = init_population(ppl_sz,num_blk_x,num_blk_y,num_blk)

bst = 0
bstcst = compute_cost(population[0],blocks,num_blk_x,num_blk_y)
for i in range(len(population)):
    cost = compute_cost(population[i],blocks,num_blk_x,num_blk_y)
    if cost <= bstcst:
        bst = i
        bstcst = cost
print(bstcst)
visual_specie(population[bst],blocks)
# Out:
# 285190.0

# %%
visual_specie(np.arange(num_blk).reshape(num_blk_x,num_blk_y),blocks)
compute_cost(np.arange(num_blk).reshape(num_blk_x,num_blk_y),blocks,num_blk_x,num_blk_y)
# Out:
# 95271.0

# %%
for gen in range(curr_gen,total_gen):
    elite = elite_species(population,blocks,num_blk_x,num_blk_y,elite_pt)
    if gen%50==0:
        print("Elite diversity: "+str(elite_diversity(elite)))
    """
    mip = 1000000000
    for i in population:
        mip = min(mip,compute_cost(i,blocks,num_blk_x,num_blk_y))
    mie = 1000000000
    for i in elite:
        mie = min(mie,compute_cost(i,blocks,num_blk_x,num_blk_y))
    print("mip: "+str(mip))
    print("mie: "+str(mie))
    print("elite[0]: "+str(compute_cost(elite[0],blocks,num_blk_x,num_blk_y)))
    """
    #print(elite)
    random.shuffle(population)
    #print(elite)
    new_population = population[:]

    #print(elite)
    #print(new_population)
    for i in range(0,len(population),2):
        cross_pbt = random.random()
        if cross_pbt<0.7:
            p1,p2 = crossover1(population[i],population[i+1],blocks,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y)
            new_population.append(p1)
            new_population.append(p2)

    """
    mix = 1000000000
    #print("cost: "+str(compute_cost(new_population[0],blocks,num_blk_x,num_blk_y)))
    #print("elite[0]: "+str(compute_cost(elite[0],blocks,num_blk_x,num_blk_y)))
    #print((new_population[0]==elite[0]))
    #print(compute_cost(new_population[0],blocks,num_blk_x,num_blk_y) == compute_cost(elite[0],blocks,num_blk_x,num_blk_y))
    for i in new_population:
        mix = min(mix,compute_cost(i,blocks,num_blk_x,num_blk_y))
    print("mix: "+str(mix))
    """
    for i in range(0,len(new_population)):
        if random.random()<0.1:
            new_population.append(mutate(new_population[i],blocks,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y))
        elif random.random()<0.1:
            new_population.append(self_mutate(new_population[i],blocks,num_blk_x,num_blk_y,blk_sz_x,blk_sz_y))

    #print(elite)
    #new_population.extend(elite)

    population = next_gen(new_population,blocks,num_blk_x,num_blk_y,ppl_sz)
    """
    mid = 1000000000
    for i in population:
        mid = min(mid,compute_cost(i,blocks,num_blk_x,num_blk_y))
    print("mid: "+str(mid))
    """
    best_specie_gen.append(population[0])
    if gen%10==9:
        print(str(gen+1)+" generation completed. Best cost: "+str(compute_cost(best_specie_gen[-1],blocks,num_blk_x,num_blk_y)))
    
    curr_gen += 1
# Out:
# Elite diversity: 4
# 1510 generation completed. Best cost: 138721.0
# 1520 generation completed. Best cost: 138721.0
# 1530 generation completed. Best cost: 138721.0
# 1540 generation completed. Best cost: 138721.0
# 1550 generation completed. Best cost: 137697.0
# Elite diversity: 3
# 1560 generation completed. Best cost: 137697.0
# 1570 generation completed. Best cost: 137697.0
# 1580 generation completed. Best cost: 137697.0
# 1590 generation completed. Best cost: 137697.0
# 1600 generation completed. Best cost: 137697.0
# Elite diversity: 3
# 1610 generation completed. Best cost: 137697.0
# 1620 generation completed. Best cost: 137697.0
# 1630 generation completed. Best cost: 137697.0
# 1640 generation completed. Best cost: 137697.0
# 1650 generation completed. Best cost: 137697.0
# Elite diversity: 5
# 1660 generation completed. Best cost: 137697.0
# 1670 generation completed. Best cost: 137697.0
# 1680 generation completed. Best cost: 137697.0
# 1690 generation completed. Best cost: 137697.0
# 1700 generation completed. Best cost: 137697.0
# Elite diversity: 3
# 1710 generation completed. Best cost: 137697.0
# 1720 generation completed. Best cost: 137175.0
# 1730 generation completed. Best cost: 137175.0
# 1740 generation completed. Best cost: 137175.0
# 1750 generation completed. Best cost: 137175.0
# Elite diversity: 4
# 1760 generation completed. Best cost: 137045.0
# 1770 generation completed. Best cost: 137045.0
# 1780 generation completed. Best cost: 137045.0
# 1790 generation completed. Best cost: 137045.0
# 1800 generation completed. Best cost: 137045.0
# Elite diversity: 4
# 1810 generation completed. Best cost: 137045.0
# 1820 generation completed. Best cost: 137045.0
# 1830 generation completed. Best cost: 137045.0
# 1840 generation completed. Best cost: 137045.0
# 1850 generation completed. Best cost: 137045.0
# Elite diversity: 3
# 1860 generation completed. Best cost: 137045.0
# 1870 generation completed. Best cost: 137045.0
# 1880 generation completed. Best cost: 137045.0
# 1890 generation completed. Best cost: 137045.0
# 1900 generation completed. Best cost: 137045.0
# Elite diversity: 2
# 1910 generation completed. Best cost: 137045.0
# 1920 generation completed. Best cost: 137045.0
# 1930 generation completed. Best cost: 137045.0
# 1940 generation completed. Best cost: 137045.0
# 1950 generation completed. Best cost: 137045.0
# Elite diversity: 3
# 1960 generation completed. Best cost: 137045.0
# 1970 generation completed. Best cost: 137045.0
# 1980 generation completed. Best cost: 137045.0
# 1990 generation completed. Best cost: 137045.0
# 2000 generation completed. Best cost: 137045.0
# Elite diversity: 2
# 2010 generation completed. Best cost: 136471.0
# 2020 generation completed. Best cost: 136471.0
# 2030 generation completed. Best cost: 136471.0
# 2040 generation completed. Best cost: 136471.0
# 2050 generation completed. Best cost: 136471.0
# Elite diversity: 4
# 2060 generation completed. Best cost: 136471.0
# 2070 generation completed. Best cost: 136471.0
# 2080 generation completed. Best cost: 136471.0
# 2720 generation completed. Best cost: 132902.0
# 2730 generation completed. Best cost: 132902.0
# 2740 generation completed. Best cost: 132902.0
# 2750 generation completed. Best cost: 132902.0
# Elite diversity: 4
# 2760 generation completed. Best cost: 132902.0
# 2770 generation completed. Best cost: 132902.0
# 2780 generation completed. Best cost: 132902.0
# 2790 generation completed. Best cost: 132902.0
# 2800 generation completed. Best cost: 132902.0
# Elite diversity: 4
# 2810 generation completed. Best cost: 132902.0
# 2820 generation completed. Best cost: 132902.0
# 2830 generation completed. Best cost: 132877.0
# 2840 generation completed. Best cost: 132877.0
# 2850 generation completed. Best cost: 132711.0
# Elite diversity: 4
# 2860 generation completed. Best cost: 132711.0
# 2870 generation completed. Best cost: 132650.0
# 2880 generation completed. Best cost: 132650.0
# 2890 generation completed. Best cost: 132650.0
# 2900 generation completed. Best cost: 132650.0
# Elite diversity: 4
# 2910 generation completed. Best cost: 132650.0
# 2920 generation completed. Best cost: 132650.0
# 2930 generation completed. Best cost: 132650.0
# 2940 generation completed. Best cost: 132650.0
# 2950 generation completed. Best cost: 132650.0
# Elite diversity: 5
# 2960 generation completed. Best cost: 132650.0
# 2970 generation completed. Best cost: 132650.0
# 2980 generation completed. Best cost: 132618.0
# 2990 generation completed. Best cost: 132618.0
# 3000 generation completed. Best cost: 132618.0
# Elite diversity: 4
# 3010 generation completed. Best cost: 132618.0
# 3020 generation completed. Best cost: 132618.0
# 3030 generation completed. Best cost: 132618.0
# 3040 generation completed. Best cost: 132618.0
# 3050 generation completed. Best cost: 132618.0
# Elite diversity: 4
# 3060 generation completed. Best cost: 132618.0
# 3070 generation completed. Best cost: 132618.0
# 3080 generation completed. Best cost: 132618.0
# 3090 generation completed. Best cost: 132530.0
# 3100 generation completed. Best cost: 132530.0
# Elite diversity: 3
# 3110 generation completed. Best cost: 132530.0
# 3120 generation completed. Best cost: 132530.0
# 3130 generation completed. Best cost: 132530.0
# 3140 generation completed. Best cost: 132530.0
# 3150 generation completed. Best cost: 132530.0
# Elite diversity: 4
# 3160 generation completed. Best cost: 132530.0
# 3170 generation completed. Best cost: 132530.0
# 3180 generation completed. Best cost: 132453.0
# 3190 generation completed. Best cost: 132453.0
# 3200 generation completed. Best cost: 132453.0
# Elite diversity: 3
# 3210 generation completed. Best cost: 132453.0
# 3220 generation completed. Best cost: 132453.0
# 3230 generation completed. Best cost: 132453.0
# 3240 generation completed. Best cost: 132453.0
# 3250 generation completed. Best cost: 132453.0
# Elite diversity: 3
# 3260 generation completed. Best cost: 132453.0
# 3270 generation completed. Best cost: 132453.0
# 3280 generation completed. Best cost: 132453.0
# 3290 generation completed. Best cost: 132453.0
# 3300 generation completed. Best cost: 132453.0
# Elite diversity: 4
# 3310 generation completed. Best cost: 132453.0
# 3320 generation completed. Best cost: 132453.0
# 3330 generation completed. Best cost: 132453.0
# 3340 generation completed. Best cost: 132453.0
# Elite diversity: 4
# 4610 generation completed. Best cost: 128188.0
# 4620 generation completed. Best cost: 128188.0
# 4630 generation completed. Best cost: 128188.0
# 4640 generation completed. Best cost: 128188.0
# 4650 generation completed. Best cost: 128188.0
# Elite diversity: 4
# 4660 generation completed. Best cost: 128188.0
# 4670 generation completed. Best cost: 128188.0
# 4680 generation completed. Best cost: 128188.0
# 4690 generation completed. Best cost: 128188.0
# 4700 generation completed. Best cost: 128188.0
# Elite diversity: 4
# 4710 generation completed. Best cost: 127792.0
# 4720 generation completed. Best cost: 127700.0
# 4730 generation completed. Best cost: 127700.0
# 4740 generation completed. Best cost: 127700.0
# 4750 generation completed. Best cost: 127386.0
# Elite diversity: 2
# 4760 generation completed. Best cost: 127386.0
# 4770 generation completed. Best cost: 127386.0
# 4780 generation completed. Best cost: 127386.0
# 4790 generation completed. Best cost: 127386.0
# 4800 generation completed. Best cost: 127386.0
# Elite diversity: 2
# 4810 generation completed. Best cost: 127386.0
# 4820 generation completed. Best cost: 127386.0
# 4830 generation completed. Best cost: 127386.0
# 4840 generation completed. Best cost: 127386.0
# 4850 generation completed. Best cost: 127386.0
# Elite diversity: 4
# 4860 generation completed. Best cost: 127386.0
# 4870 generation completed. Best cost: 127386.0
# 4880 generation completed. Best cost: 127386.0
# 4890 generation completed. Best cost: 127386.0
# 4900 generation completed. Best cost: 127386.0
# Elite diversity: 4
# 4910 generation completed. Best cost: 126908.0
# 4920 generation completed. Best cost: 126908.0
# 4930 generation completed. Best cost: 126908.0
# 4940 generation completed. Best cost: 126908.0
# 4950 generation completed. Best cost: 126371.0
# Elite diversity: 3
# 4960 generation completed. Best cost: 126371.0
# 4970 generation completed. Best cost: 126371.0
# 4980 generation completed. Best cost: 126371.0
# 4990 generation completed. Best cost: 126371.0
# 5000 generation completed. Best cost: 126371.0

# %%
total_gen = 5000

# %%
ind = -1
visual_specie(best_specie_gen[ind],blocks)
compute_cost(best_specie_gen[ind],blocks,num_blk_x,num_blk_y)
# Out:
# 126371.0

# %%
y = []
x = []
for i in range(len(best_specie_gen)):
    y.append(compute_cost(best_specie_gen[i],blocks,num_blk_x,num_blk_y))
    x.append(i+1)
plt.plot(x,y)

# %%
ind = 75
visual_specie(best_specie_gen[ind],blocks)
compute_cost(best_specie_gen[ind],blocks,num_blk_x,num_blk_y)
# Out:
# 137236.0

# %%
total_gen = 3000

# %%
print(len(best_specie_gen))
# Out:
# 100

# %%
visual_specie(best_specie_gen[9998],blocks)
compute_cost(best_specie_gen[9998],blocks,num_blk_x,num_blk_y)
# Out:
# 20960

# %%
visual_specie(best_specie_gen[-1],blocks)
compute_cost(best_specie_gen[-1],blocks,num_blk_x,num_blk_y)
# Out:
# 20416

# %%
with open("16*16_10k-gen.pkl","wb") as f:
    pickle.dump([best_specie_gen, population, curr_gen],f)

# %%
visual_specie(population[0],blocks)
